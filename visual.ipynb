# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance = pd.read_csv('data/StudentsPerformance.csv')

# %%
students_performance = students_performance.rename(columns={
    'race/ethnicity' :'race_ethnicity', 
    'parental level of education': 'parental_level_of_education',
    'test preparation course': 'test_preparation_course',
    'math score': 'math_score',
    'reading score': 'reading_score',
    'writing score': 'writing_score'
})
students_performance.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.math_score.hist()
# Out:
# <Axes: >

# %%
students_performance.plot.scatter(x='math_score',y='reading_score')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
sns.lmplot(students_performance, x='math_score',y='reading_score', hue='gender')

# %%
df = pd.read_csv('data/income.csv')

# %%
df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.income.plot()
# Out:
# <Axes: >

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <Axes: ylabel='income'>

# %%
df.plot(kind='line')
# Out:
# <Axes: >

# %%
df['income'].plot()
# Out:
# <Axes: >

# %%
df.plot()
# Out:
# <Axes: >

# %%
plt.plot(df.index, df.income)

# %%
df1 = pd.read_csv('data/dataset_209770_6.txt', sep=' ')

# %%
df1.head()
# Out:
#              x            y
# 0   706.228394   388.676902
# 1  1386.748920  1504.130873
# 2   714.385542   408.783312
# 3  1384.407503  1508.047957
# 4   406.347778  1295.943566

# %%
sns.lmplot(df1, x='x',y='y')

# %%
sns.clustermap(df1)

# %%
df3 = pd.read_csv('data/genome_matrix.csv', index_col=0)

# %%
df3.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(df3,cmap="viridis")
# Out:
# <Axes: >

# %%
iris = pd.read_csv('data/iris.csv', index_col=0)

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.kdeplot(iris.drop("species", axis=1))
# Out:
# <Axes: ylabel='Density'>

# %%
sns.violinplot(iris['petal length'])
# Out:
# <Axes: >

# %%
sns.pairplot(iris.drop("species", axis=1))
